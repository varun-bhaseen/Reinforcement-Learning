# %% [markdown]
# <a href="https://colab.research.google.com/github/varun-bhaseen/Reinforcement-Learning/blob/master/RL_Midterm_Stu_Id_014538212_Bhaseen_Varun.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Midterm Exam
#
# ## Problem 1 (70 pts):
# 1. Use the Q-learning example as the base code and compare the SARSA and Q-learning approach
# based on the same setting for the learning rate (alpha) and the discount factor (gamma).
# 2. Observe the performance of the learning algorithms by changing the learning rate by 4 values
# and gamma by 2.
# 3. Tabulate/plot the performance vs. the changes in these two hyperparameters and elaborate on
# the results.
# 4. Submit your code and the report on Canvas by the due date.
#
# ## Problem 2 (30):
# 1. How does Q-learning different from the state value-based learning?
# 2. Is it possible for the agent to rely on the state value-based learning approach to achieve its goal?
# 3. What kind of information does the agent need in order to use each approach (Q-learning and
# State value-based)?
# 4. Is there a systematic way to determine which action value-based learning method (Q-learning
# and SARSA) is a better choice and can achieve better results? Explain.

# %%
# !pip install tensorboardX
# Out:
# Requirement already satisfied: tensorboardX in /usr/local/lib/python3.6/dist-packages (2.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from tensorboardX) (1.15.0)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorboardX) (3.12.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from tensorboardX) (1.18.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.8.0->tensorboardX) (50.3.0)

# %%
# !rm -r ./runs/

# %%
from tensorboardX import SummaryWriter
writer = SummaryWriter()

# %load_ext tensorboard

# %%
import gym
import numpy as np

MAX_NUM_EPISODES = 25000
STEPS_PER_EPISODE = 200 #  This is specific to MountainCar. May change with env
EPSILON_MIN = 0.005
max_num_steps = MAX_NUM_EPISODES * STEPS_PER_EPISODE
EPSILON_DECAY = 500 * EPSILON_MIN / max_num_steps
ALPHA = 0.05  # Learning rate
GAMMA = 0.98  # Discount factor
NUM_DISCRETE_BINS = 30  # Number of bins to Discretize each observation dim

class Q_Learner(object):
    def __init__(self, env):
        self.obs_shape = env.observation_space.shape
        self.obs_high = env.observation_space.high
        self.obs_low = env.observation_space.low
        self.obs_bins = NUM_DISCRETE_BINS  # Number of bins to Discretize each observation dim
        self.bin_width = (self.obs_high - self.obs_low) / self.obs_bins
        self.action_shape = env.action_space.n
        # Create a multi-dimensional array (aka. Table) to represent the
        # Q-values
        self.Q = np.zeros((self.obs_bins + 1, self.obs_bins + 1,
                           self.action_shape))  # (51 x 51 x 3)
        self.alpha = ALPHA  # Learning rate
        self.gamma = GAMMA  # Discount factor
        self.epsilon = 1.0

    def discretize(self, obs):
        return tuple(((obs - self.obs_low) / self.bin_width).astype(int))

    def get_action(self, obs):
        discretized_obs = self.discretize(obs)
        # Epsilon-Greedy action selection
        if self.epsilon > EPSILON_MIN:
            self.epsilon -= EPSILON_DECAY
        if np.random.random() > self.epsilon:
            return np.argmax(self.Q[discretized_obs])
        else:  # Choose a random action
            return np.random.choice([a for a in range(self.action_shape)])

    def learn(self, obs, action, reward, next_obs):
        discretized_obs = self.discretize(obs)
        discretized_next_obs = self.discretize(next_obs)
        td_target = reward + self.gamma * np.max(self.Q[discretized_next_obs])
        td_error = td_target - self.Q[discretized_obs][action]
        self.Q[discretized_obs][action] += self.alpha * td_error

def q_train(agent, env):
    best_reward = -float('inf')
    with SummaryWriter() as writer:

      for episode in range(MAX_NUM_EPISODES):
          done = False
          obs = env.reset()
          total_reward = 0.0
          while not done:
              action = agent.get_action(obs)
              next_obs, reward, done, info = env.step(action)
              agent.learn(obs, action, reward, next_obs)
              obs = next_obs
              total_reward += reward
          if total_reward > best_reward:
              best_reward = total_reward
          print("Q-Learn Episode#:{} reward:{} best_reward:{} eps:{}".format(episode,
                                      total_reward, best_reward, agent.epsilon))
          # writer.add_scalar('Q-Learner', episode, total_reward)
          
          # writer.add_hparams({'learning_rate': agent.alpha, 'discount_factor': agent.gamma,
          #                 'epsilon': agent.epsilon}, {'reward': total_reward, 'best_reward': best_reward})

          stats = {'learning_rate': agent.alpha, 'discount_factor': agent.gamma,
                  'epsilon': agent.epsilon, 'reward': reward, 
                  'best_reward': best_reward, 'total_reward': total_reward}
          
          writer.add_scalars('Q_LearnAgent', stats, episode)

      # Return the trained policy
      return np.argmax(agent.Q, axis=2)

def q_test(agent, env, policy):
    done = False
    obs = env.reset()
    total_reward = 0.0
    while not done:
        action = policy[agent.discretize(obs)]
        next_obs, reward, done, info = env.step(action)
        obs = next_obs
        total_reward += reward
    return total_reward

# if __name__ == "__main__":
#     env = gym.make('MountainCar-v0')
#     # env = gym.wrappers.Monitor(env, "recording", force=True)
    
#     agent = Q_Learner(env)
#     learned_policy = train(agent, env)
#     # Use the Gym Monitor wrapper to evalaute the agent and record video
#     # gym_monitor_path = "./gym_monitor_output"
#     # env = gym.wrappers.Monitor(env, gym_monitor_path, force=True)
#     writer.flush()
#     for _ in range(1000):
#         test(agent, env, learned_policy)
#     env.close()

# %%
# !pip install gym pyvirtualdisplay
# !apt-get install -y xvfb python-opengl ffmpeg

# %%
import gym
import numpy as np
# from pyvirtualdisplay import Display
import math
# import glob
# import io
# import base64
# from IPython.display import HTML
from gym import logger as gymlogger
# import IPython.display as ipythondisplay

# gymlogger.set_level(40) #error only

# display = Display(visible=0, size=(1400, 900))
# display.start()

MAX_NUM_EPISODES = 25000
STEPS_PER_EPISODE = 200 #  This is specific to MountainCar. May change with env
EPSILON_MIN = 0.005
max_num_steps = MAX_NUM_EPISODES * STEPS_PER_EPISODE
EPSILON_DECAY = 500 * EPSILON_MIN / max_num_steps

ALPHA = 0.05  # Learning rate

GAMMA = 0.99  # Discount factor
NUM_DISCRETE_BINS = 30  # Number of bins to Discretize each observation dim

class SARSA_Learner(object):
    def __init__(self, env):
        self.obs_shape = env.observation_space.shape
        self.obs_high = env.observation_space.high
        self.obs_low = env.observation_space.low
        
        self.obs_bins = NUM_DISCRETE_BINS  # Number of bins to Discretize each observation dim
        self.bin_width = (self.obs_high - self.obs_low) / self.obs_bins
        self.action_shape = env.action_space.n #n_action = action_shape
        # Create a multi-dimensional array (aka. Table) to represent the
        # Q-values
        self.Q = np.zeros((self.obs_bins + 1, self.obs_bins + 1,
                           self.action_shape))  # (51 x 51 x 3)
        
        
        self.env_den = self.bin_width
        self.pos_den = self.env_den[0]    
        self.vel_den = self.env_den[1]
        self.pos_high = self.obs_high[0]    
        self.pos_low = self.obs_low[0]    
        self.vel_high = self.obs_high[1]    
        self.vel_low = self.obs_low[1]
        
        
        self.gamma = GAMMA  # Discount factor
        self.epsilon = 1.0

        self.alpha = ALPHA
        
#         self.alpha = max(EPSILON_MIN,self.epsilon*(self.gamma**(episode//100)))  # Learning rate

    def discretize(self, obs):
        
        
        self.pos_scaled = int((obs[0] - self.pos_low)/self.pos_den)  #converts to an integer value    
        self.vel_scaled = int((obs[1] - self.vel_low)/self.vel_den)  #converts to an integer value
        
        return self.pos_scaled, self.vel_scaled

    def get_action(self, obs):
        
        pos, vel = self.discretize(obs)
        
        # Epsilon-Greedy action selection
        
           #action for the initial state using epsilon greedy   
        if self.epsilon > EPSILON_MIN:
            self.epsilon -= EPSILON_DECAY

        if np.random.uniform(low=0,high=1) > self.epsilon:        
            a = np.random.choice(env.action_space.n)
            return a
        else:        
#             pos,vel = discretize(obs)        
            a = np.argmax(self.Q[pos][vel])
            return a

        
#         if self.epsilon > EPSILON_MIN:
#             self.epsilon -= EPSILON_DECAY
        
#         if np.random.random() > self.epsilon:
#             return np.argmax(self.Q[discretized_obs])
        
#         else:  # Choose a random action
#             return np.random.choice([a for a in range(self.action_shape)])

    def learn(self, obs, action, reward, next_obs):
        
        pos, vel = self.discretize(obs)
        
        pos_, vel_ = self.discretize(next_obs)
        
        td_target = reward + self.gamma * np.max(self.Q[pos_][vel_][action])
        
        """
        Formula picked from below source
        https://learning.oreilly.com/library/view/reinforcement-learning-with/9781788835725/ffd21cf7-d907-45e6-a897-8762c9a20f2d.xhtml
        """
        
        self.Q[pos][vel][action] = (1 - self.alpha)*self.Q[pos][vel][action] + self.alpha * td_target
        
#         td_error = td_target - self.Q[pos][vel][action]
        
#         self.Q[pos][vel][action] = (1 - self.alpha)
        
#         self.Q[pos][vel][action] += self.alpha * td_error

def sarsa_train(agent, env):
    best_reward = -float('inf')
    with SummaryWriter() as writer:

      for episode in range(MAX_NUM_EPISODES):
          done = False
          obs = env.reset()
          total_reward = 0.0
  #         alpha = max(EPSILON_MIN,self.epsilon*(gamma**(episode//100)))
          while not done:
              action = agent.get_action(obs)
              next_obs, reward, done, info = env.step(action)
              agent.learn(obs, action, reward, next_obs)
              obs = next_obs
              total_reward += reward
          if total_reward > best_reward:
              best_reward = total_reward
          print("SARSA Episode#:{} reward:{} best_reward:{} eps:{}".format(episode,
                                      total_reward, best_reward, agent.epsilon))
          # writer.add_scalar('SARSA', episode, total_reward)
          
          # writer.add_hparams({'learning_rate': agent.alpha, 'discount_factor': agent.gamma,
          #                 'epsilon': agent.epsilon}, {'reward': total_reward, 'best_reward': best_reward})          
        
          stats = {'learning_rate': agent.alpha, 'discount_factor': agent.gamma,
                  'epsilon': agent.epsilon, 'reward': reward, 
                  'best_reward': best_reward, 'total_reward': total_reward}
          
          writer.add_scalars('SARSA_LearnAgent', stats, episode)
        
        # show_video()
    # Return the trained policy
    return np.argmax(agent.Q, axis=2)

def sarsa_test(agent, env, policy):
    done = False
    obs = env.reset()
    total_reward = 0.0
    while not done:
        action = policy[agent.discretize(obs)]
        next_obs, reward, done, info = env.step(action)
        obs = next_obs
        total_reward += reward
    return total_reward

# def show_video():
#   mp4list = glob.glob('video/*.mp4')
#   if len(mp4list) > 0:
#     mp4 = mp4list[0]
#     video = io.open(mp4, 'r+b').read()
#     encoded = base64.b64encode(video)
#     ipythondisplay.display(HTML(data='''<video alt="test" autoplay 
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,{0}" type="video/mp4" />
#              </video>'''.format(encoded.decode('ascii'))))
#   else: 
#     print("Could not find video")

# def wrap_env(env):
#   env = gym.wrappers.Monitor(env, './video', force=True)
#   return env

# if __name__ == "__main__":
#     # env = wrap_env(gym.make('MountainCar-v0')) #wrapping the env to render as a video
#     env = gym.make('MountainCar-v0')
#     # env = gym.wrappers.Monitor(env, "recording", force=True)
    
#     sarsa_agent = SARSA_Learner(env)
#     sarsa_learned_policy = train(sarsa_agent, env)
#     # Use the Gym Monitor wrapper to evalaute the agent and record video
#     # gym_monitor_path = "./gym_monitor_output"
#     # env = gym.wrappers.Monitor(env, gym_monitor_path, force=True)
#     # show_video()
#     # writer.flush()
    
#     q_agent = Q_Learner(env)
#     q_learned_policy = train(q_agent, env)
#     # Use the Gym Monitor wrapper to evalaute the agent and record video
#     # gym_monitor_path = "./gym_monitor_output"
#     # env = gym.wrappers.Monitor(env, gym_monitor_path, force=True)
#     writer.flush()
    
#     for _ in range(1000):
#         test_1 = test(q_agent, env, q_learned_policy)
#         test_2 = test(sarsa_agent, env, sarsa_learned_policy)
#         # show_video()
#     env.close()

# %%
if __name__ == "__main__":
    
    env = gym.make('MountainCar-v0')
    
    sarsa_agent = SARSA_Learner(env)  
    q_agent = Q_Learner(env)
    
    sarsa_learned_policy = sarsa_train(sarsa_agent, env)
    q_learned_policy = q_train(q_agent, env)
    
    writer.flush()
    
    for _ in range(1000):
        test_1 = q_test(q_agent, env, q_learned_policy)
        test_2 = sarsa_test(sarsa_agent, env, sarsa_learned_policy)
        # show_video()
    env.close()
# Out:
# Streaming output truncated to the last 5000 lines.
# SARSA Episode#:20001 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20002 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20003 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20004 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20005 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20006 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20007 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20008 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20009 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20010 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20011 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20012 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20013 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20014 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20015 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20016 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20017 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20018 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20019 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20020 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20021 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20022 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20023 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20024 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20025 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20026 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20027 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20028 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20029 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20030 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20031 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20032 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20033 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20034 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20035 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20036 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20037 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20038 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20039 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20040 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20041 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20042 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20043 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20044 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20045 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20046 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20047 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20048 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20049 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20050 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20051 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20052 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20053 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20054 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20055 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20056 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20057 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20058 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20059 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20060 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20061 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20062 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20063 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20064 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20065 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20066 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20067 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20068 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20069 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20070 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20071 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20072 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20073 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20074 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20075 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20076 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20077 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20078 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20079 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20080 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20081 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20082 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20083 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20084 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20085 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20086 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20087 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20088 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20089 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20090 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20091 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20092 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20093 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20094 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20095 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20096 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20097 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20098 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20099 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20100 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20101 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20102 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20103 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20104 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20105 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20106 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20107 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20108 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20109 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20110 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20111 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20112 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20113 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20114 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20115 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20116 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20117 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20118 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20119 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20120 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20121 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20122 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20123 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20124 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20125 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20126 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20127 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20128 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20129 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20130 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20131 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20132 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20133 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20134 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20135 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20136 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20137 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20138 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20139 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20140 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20141 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20142 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20143 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20144 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20145 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20146 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20147 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20148 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20149 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20150 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20151 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20152 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20153 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20154 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20155 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20156 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20157 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20158 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20159 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20160 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20161 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20162 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20163 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20164 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20165 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20166 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20167 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20168 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20169 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20170 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20171 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20172 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20173 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20174 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20175 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20176 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20177 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20178 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20179 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20180 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20181 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20182 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20183 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20184 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20185 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20186 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20187 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20188 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20189 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20190 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20191 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20192 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20193 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20194 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20195 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20196 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20197 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20198 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20199 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20200 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20201 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20202 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20203 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20204 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20205 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20206 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20207 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20208 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20209 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20210 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20211 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20212 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20213 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20214 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20215 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20216 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20217 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20218 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20219 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20220 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20221 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20222 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20223 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20224 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20225 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20226 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20227 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20228 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20229 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20230 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20231 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20232 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20233 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20234 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20235 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20236 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20237 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20238 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20239 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20240 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20241 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20242 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20243 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20244 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20245 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20246 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20247 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20248 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20249 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20250 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20251 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20252 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20253 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20254 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20255 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20256 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20257 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20258 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20259 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20260 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20261 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20262 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20263 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20264 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20265 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20266 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20267 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20268 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20269 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20270 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20271 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20272 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20273 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20274 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20275 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20276 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20277 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20278 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20279 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20280 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20281 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20282 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20283 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20284 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20285 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20286 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20287 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20288 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20289 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20290 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20291 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20292 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20293 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20294 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20295 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20296 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20297 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20298 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20299 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20300 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20301 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20302 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20303 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20304 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20305 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20306 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20307 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20308 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20309 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20310 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20311 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20312 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20313 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20314 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20315 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20316 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20317 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20318 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20319 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20320 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20321 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20322 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20323 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20324 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20325 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20326 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20327 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20328 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20329 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20330 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20331 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20332 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20333 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20334 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20335 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20336 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20337 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20338 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20339 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20340 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20341 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20342 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20343 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20344 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20345 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20346 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20347 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20348 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20349 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20350 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20351 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20352 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20353 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20354 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20355 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20356 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20357 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20358 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20359 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20360 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20361 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20362 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20363 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20364 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20365 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20366 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20367 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20368 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20369 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20370 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20371 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20372 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20373 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20374 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20375 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20376 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20377 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20378 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20379 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20380 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20381 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20382 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20383 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20384 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20385 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20386 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20387 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20388 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20389 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20390 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20391 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20392 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20393 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20394 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20395 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20396 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20397 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20398 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20399 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20400 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20401 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20402 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20403 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20404 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20405 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20406 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20407 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20408 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20409 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20410 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20411 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20412 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20413 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20414 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20415 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20416 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20417 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20418 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20419 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20420 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20421 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20422 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20423 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20424 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20425 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20426 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20427 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20428 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20429 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20430 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20431 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20432 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20433 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20434 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20435 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20436 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20437 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20438 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20439 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20440 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20441 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20442 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20443 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20444 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20445 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20446 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20447 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20448 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20449 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20450 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20451 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20452 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20453 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20454 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20455 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20456 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20457 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20458 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20459 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20460 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20461 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20462 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20463 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20464 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20465 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20466 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20467 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20468 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20469 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20470 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20471 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20472 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20473 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20474 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20475 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20476 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20477 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20478 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20479 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20480 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20481 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20482 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20483 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20484 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20485 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20486 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20487 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20488 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20489 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20490 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20491 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20492 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20493 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20494 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20495 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20496 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20497 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20498 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20499 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20500 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20501 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20502 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20503 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20504 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20505 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20506 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20507 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20508 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20509 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20510 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20511 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20512 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20513 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20514 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20515 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20516 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20517 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20518 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20519 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20520 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20521 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20522 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20523 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20524 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20525 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20526 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20527 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20528 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20529 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20530 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20531 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20532 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20533 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20534 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20535 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20536 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20537 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20538 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20539 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20540 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20541 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20542 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20543 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20544 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20545 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20546 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20547 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20548 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20549 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20550 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20551 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20552 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20553 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20554 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20555 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20556 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20557 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20558 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20559 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20560 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20561 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20562 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20563 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20564 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20565 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20566 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20567 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20568 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20569 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20570 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20571 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20572 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20573 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20574 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20575 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20576 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20577 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20578 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20579 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20580 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20581 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20582 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20583 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20584 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20585 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20586 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20587 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20588 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20589 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20590 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20591 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20592 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20593 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20594 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20595 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20596 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20597 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20598 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20599 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20600 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20601 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20602 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20603 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20604 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20605 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:20606 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# ...
# SARSA Episode#:24798 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24799 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24800 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24801 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24802 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24803 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24804 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24805 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24806 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24807 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24808 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24809 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24810 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24811 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24812 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24813 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24814 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24815 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24816 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24817 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24818 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24819 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24820 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24821 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24822 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24823 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24824 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24825 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24826 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24827 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24828 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24829 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24830 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24831 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24832 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24833 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24834 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24835 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24836 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24837 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24838 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24839 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24840 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24841 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24842 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24843 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24844 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24845 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24846 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24847 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24848 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24849 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24850 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24851 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24852 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24853 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24854 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24855 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24856 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24857 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24858 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24859 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24860 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24861 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24862 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24863 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24864 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24865 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24866 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24867 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24868 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24869 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24870 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24871 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24872 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24873 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24874 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24875 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24876 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24877 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24878 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24879 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24880 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24881 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24882 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24883 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24884 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24885 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24886 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24887 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24888 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24889 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24890 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24891 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24892 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24893 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24894 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24895 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24896 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24897 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24898 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24899 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24900 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24901 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24902 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24903 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24904 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24905 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24906 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24907 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24908 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24909 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24910 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24911 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24912 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24913 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24914 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24915 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24916 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24917 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24918 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24919 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24920 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24921 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24922 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24923 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24924 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24925 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24926 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24927 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24928 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24929 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24930 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24931 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24932 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24933 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24934 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24935 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24936 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24937 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24938 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24939 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24940 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24941 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24942 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24943 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24944 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24945 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24946 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24947 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24948 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24949 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24950 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24951 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24952 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24953 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24954 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24955 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24956 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24957 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24958 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24959 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24960 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24961 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24962 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24963 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24964 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24965 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24966 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24967 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24968 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24969 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24970 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24971 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24972 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24973 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24974 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24975 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24976 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24977 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24978 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24979 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24980 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24981 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24982 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24983 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24984 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24985 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24986 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24987 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24988 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24989 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24990 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24991 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24992 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24993 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24994 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24995 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24996 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24997 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24998 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707
# SARSA Episode#:24999 reward:-200.0 best_reward:-155.0 eps:0.004999500037173707

# %% [markdown]
# ## Conclusion:
#
# 1.	Use the Q-learning example as the base code and compare the SARSA and Q-learning approach based on the same setting for the learning rate (alpha) and the discount factor (gamma).
#
# *   Q-Learner is coverging faster as compared to SARSA on same learning rate and Discount factor. The Reason for that is because Q-Learner takes a greedy approach so it takes in larger values to converge as fast as possible for maximising awards
#
#
# 2.	Observe the performance of the learning algorithms by changing the learning rate by 4 values and gamma by 2.
#
# *   The Discount Factor Gamma is decayed dynamically over a range of values after each 185 steps and as observed the Q-Learner is performing better even as gamma is decaying whereas SARSA is not coverging sooner. The Learning rate (alpha) is also changed dynamically over time after every 100000 episodes. SARSA works poorly as it takes smaller steps over smaller learning rate as opposed to Q-Learning which is following a curve for convergence
#
# 3.  Tabulate/plot the performance vs. the changes in these two hyperparameters and elaborate on the results.
#
#
# *   The Learning rate is dynamically changed over time and we can see the performance changing drastically for SARSA. This is due to the fact that SARSA takes a more conservative approach and as learning rate reduces the ability for SARSA to converge also reduces significantly

# %%
# %tensorboard dev upload --logdir runs

# %%
# !tensorboard --logdir runs/

# %%
# !tensorboard dev upload --logdir runs
# Out:
# 2020-10-15 00:49:38.249302: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
#
# ***** TensorBoard Uploader *****
#
# This will upload your TensorBoard logs to https://tensorboard.dev/ from
# the following directory:
#
# runs
#
# This TensorBoard will be visible to everyone. Do not upload sensitive
# data.
#
# Your use of this service is subject to Google's Terms of Service
# <https://policies.google.com/terms> and Privacy Policy
# <https://policies.google.com/privacy>, and TensorBoard.dev's Terms of Service
# <https://tensorboard.dev/policy/terms/>.
#
# This notice will not be shown again while you are logged into the uploader.
# To log out, run `tensorboard dev auth revoke`.
#
# Continue? (yes/NO) yes
#
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=373649185512-8v619h5kft38l4456nm2dj4ubeqsrvh6.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=openid+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email&state=VGs71wtiWZ8k8MamtfXacRJV7GWgBk&prompt=consent&access_type=offline
# Enter the authorization code: 4/5AFIoaYIwG-klRIcvXiLtXKZkx4o7np7ZdTx-JN5sCF-hcjlP3wsRGw
#
# Data for the "hparams" plugin is now uploaded to TensorBoard.dev! Note that uploaded data is public. If you do not want to upload data for this plugin, use the "--plugins" command line argument.
# Upload started and will continue reading any new data as it's added
# to the logdir. To stop uploading, press Ctrl-C.
#
# View your TensorBoard live at: https://tensorboard.dev/experiment/lfNgRbbIQamUzf5bWkryfw/
#
# [2020-10-15T00:50:21] Uploader started.
# [2020-10-15T00:55:43] Total uploaded: 300064 scalars, 0 tensors, 0 binary objects
#
# Interrupted. View your TensorBoard at https://tensorboard.dev/experiment/lfNgRbbIQamUzf5bWkryfw/
# Traceback (most recent call last):
#   File "/usr/local/bin/tensorboard", line 8, in <module>
#     sys.exit(run_main())
#   File "/usr/local/lib/python3.6/dist-packages/tensorboard/main.py", line 75, in run_main
#     app.run(tensorboard.main, flags_parser=tensorboard.configure)
#   File "/usr/local/lib/python3.6/dist-packages/absl/app.py", line 300, in run
#     _run_main(main, args)
#   File "/usr/local/lib/python3.6/dist-packages/absl/app.py", line 251, in _run_main
#     sys.exit(main(argv))
#   File "/usr/local/lib/python3.6/dist-packages/tensorboard/program.py", line 290, in main
#     return runner(self.flags) or 0
#   File "/usr/local/lib/python3.6/dist-packages/tensorboard/uploader/uploader_subcommand.py", line 633, in run
#     return _run(flags)
#   File "/usr/local/lib/python3.6/dist-packages/tensorboard/uploader/uploader_subcommand.py", line 140, in _run
#     intent.execute(server_info, channel)
#   File "/usr/local/lib/python3.6/dist-packages/grpc/_channel.py", line 1440, in __exit__
#     self._close()
#   File "/usr/local/lib/python3.6/dist-packages/grpc/_channel.py", line 1428, in _close
#     self._channel.close(cygrpc.StatusCode.cancelled, 'Channel closed!')
#   File "src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi", line 515, in grpc._cython.cygrpc.Channel.close
#   File "src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi", line 399, in grpc._cython.cygrpc._close
#   File "src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi", line 429, in grpc._cython.cygrpc._close
#   File "/usr/lib/python3.6/threading.py", line 357, in notify_all
#     def notify_all(self):
# KeyboardInterrupt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !rm -r ./runs/

# %%
# !tensorboard dev auth revoke
# Out:
# 2020-10-15 01:11:12.776175: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Logged out of uploader.

# %%
# !cp -r runs/ drive/"My Drive"
